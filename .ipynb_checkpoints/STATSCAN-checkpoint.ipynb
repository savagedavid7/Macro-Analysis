# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
from stats_can import StatsCan
sc = StatsCan()

# %%
#df = sc.table_to_df('v2062815')

# %%
df.head(100)
# Out:
#      REF_DATE     GEO           DGUID Labour force characteristics  \
# 0  1976-01-01  Canada  2016A000011124                   Population
# 1  1976-01-01  Canada  2016A000011124                   Population
# 2  1976-01-01  Canada  2016A000011124                   Population
# 3  1976-01-01  Canada  2016A000011124                   Population
# 4  1976-01-01  Canada  2016A000011124                   Population
# ..        ...     ...             ...                          ...
# 95 1976-01-01  Canada  2016A000011124                 Labour force
# 96 1976-01-01  Canada  2016A000011124                 Labour force
# 97 1976-01-01  Canada  2016A000011124                 Labour force
# 98 1976-01-01  Canada  2016A000011124                 Labour force
# 99 1976-01-01  Canada  2016A000011124                 Labour force
#
#            Sex          Age group                               Statistics  \
# 0   Both sexes  15 years and over                                 Estimate
# 1   Both sexes  15 years and over                                 Estimate
# 2   Both sexes     15 to 64 years                                 Estimate
# 3   Both sexes     15 to 64 years                                 Estimate
# 4   Both sexes     15 to 24 years                                 Estimate
# ..         ...                ...                                      ...
# 95  Both sexes     55 to 64 years                                 Estimate
# 96  Both sexes     55 to 64 years               Standard error of estimate
# 97  Both sexes     55 to 64 years  Standard error of month-to-month change
# 98  Both sexes     55 to 64 years  Standard error of year-over-year change
# 99       Males  15 years and over                                 Estimate
#
#               Data type      UOM UOM_ID SCALAR_FACTOR SCALAR_ID      VECTOR  \
# 0   Seasonally adjusted  Persons    249     thousands         3    v2062809
# 1            Unadjusted  Persons    249     thousands         3    v2064888
# 2   Seasonally adjusted  Persons    249     thousands         3   v21580997
# 3            Unadjusted  Persons    249     thousands         3   v21580998
# 4   Seasonally adjusted  Persons    249     thousands         3    v2062836
# ..                  ...      ...    ...           ...       ...         ...
# 95           Unadjusted  Persons    249     thousands         3  v101884833
# 96  Seasonally adjusted  Persons    249     thousands         3  v101884834
# 97  Seasonally adjusted  Persons    249     thousands         3  v101884836
# 98  Seasonally adjusted  Persons    249     thousands         3  v101884838
# 99  Seasonally adjusted  Persons    249     thousands         3    v2062819
#
#      COORDINATE    VALUE STATUS SYMBOL TERMINATED DECIMALS
# 0   1.1.1.1.1.1  16852.4    NaN    NaN        NaN        1
# 1   1.1.1.1.1.2  16852.4    NaN    NaN        NaN        1
# 2   1.1.1.8.1.1  15015.9    NaN    NaN        NaN        1
# 3   1.1.1.8.1.2  15015.9    NaN    NaN        NaN        1
# 4   1.1.1.2.1.1   4509.9    NaN    NaN        NaN        1
# ..          ...      ...    ...    ...        ...      ...
# 95  1.2.1.9.1.2    985.5    NaN    NaN        NaN        1
# 96  1.2.1.9.2.1      NaN     ..    NaN        NaN        1
# 97  1.2.1.9.3.1      NaN     ..    NaN        NaN        1
# 98  1.2.1.9.4.1      NaN     ..    NaN        NaN        1
# 99  1.2.2.1.1.1   6504.3    NaN    NaN        NaN        1
#
# [100 rows x 19 columns]

# %%
data_frame = sc.vectors_to_df(["v2062815"])

# %%
data_frame
# Out:
#             v2062815
# REF_DATE
# 1976-01-01       7.1
# 1976-02-01       7.0
# 1976-03-01       6.7
# 1976-04-01       6.8
# 1976-05-01       6.9
# ...              ...
# 2020-02-01       5.6
# 2020-03-01       7.8
# 2020-04-01      13.0
# 2020-05-01      13.7
# 2020-06-01      12.3
#
# [534 rows x 1 columns]

# %%
data_frame[-365:].plot()

    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")

# %%
def create_plot(vector, data_name_short, title):
    df = sc.vectors_to_df([vector])
    #today = datetime.datetime.today().isoformat()
    
    #df = ticker_data.history(period='1d', start='2017-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(df[-100:], label=data_name_short, color='red')
    #plt.fill(df[-100:], color='red')
    plt.margins(x=0.01,tight=True)
    plt.xlabel("Date", fontdict={'fontsize':'14'})
    plt.ylabel(data_name_short, fontdict={'fontsize':'14'})
    plt.title(title, fontdict={'fontsize':'18'})
    plt.xticks(size = 14)
    plt.yticks(size = 14)
    plt.savefig(f'Images/{data_name_short}.png', bbox_inches="tight")
    
create_plot("v2062815", "Unemployment Rate", "Canada Seasonally Adjusted Estimated Unemployment Rate (15 years and over)" )
create_plot("v2062816", "Participation Rate", "Canada Seasonally Adjusted Estimated Participation Rate (15 years and over)")
create_plot("v86822775", "Budget Balance", "Canada Budget Deficit/Surplus Monthly")
create_plot("v2063948", "Ontario Unemployment", "Unemployment in Ontario Seasonally Adjusted")

# %% [markdown]
# # Trade Data Analysis

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-9dad1660b950> in <module>
# ----> 1 v1061874467
#
# NameError: name 'v1061874467' is not defined

# %%
# Plotting Price action
def create_plot(vector, data_name_short, title):
    df = sc.vectors_to_df([vector])
    #today = datetime.datetime.today().isoformat()
    
    #df = ticker_data.history(period='1d', start='2017-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(df[-24:], label=data_name_short, color='red')
    #plt.fill(df[-100:], color='red')
    plt.margins(x=0.01,tight=True)
    plt.xlabel("Date", fontdict={'fontsize':'14'})
    plt.ylabel(data_name_short, fontdict={'fontsize':'14'})
    plt.title(title, fontdict={'fontsize':'18'})
    plt.xticks(size = 14)
    plt.yticks(size = 14)
    plt.savefig(f'Images/{data_name_short}.png', bbox_inches="tight")
    
create_plot("v1061874463", "Number of Passengers", "International Passengers, number of Canadian and U.S. travellers between Canada and the United States" )

# %%
#Merchandise Trade
create_plot("v1061874472", "Merchandise trade, total export of goods", "Merchandise trade, total export of goods")
create_plot("v1061874485", "Merchandise trade, total export of goods", "Merchandise trade, total export of goods")
create_plot("v1061874499", "Domestic and international passengers, rail (VIA Rail)", "Domestic and international passengers, rail (VIA Rail)")
