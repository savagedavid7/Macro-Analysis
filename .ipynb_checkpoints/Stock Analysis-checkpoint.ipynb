# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import datetime


# %matplotlib inline

# %%
#TEST
#Tickers = ["ARKK", "ENOR", "EWC", "FXC", "FXE", "KBA", "KWEB", "XLK", "TLT"]
def get_data(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    ticker_info = ticker_data.info
    investment_name = ticker_info['shortName']
    print(investment_name)
    
    today = datetime.datetime.today().isoformat()
    print("Today is: " + today[:10])
    
    ticker_df = ticker_data.history(period='1d', start='2019-07-15', end=today[:10])
    last_price = ticker_df["Close"].iloc[-1]
    print(ticker_df)
    print(f"{investment_name} price is: ${last_price}")
    #ticker_df["Close"].plot()
get_data('TLT')
print()
#get_data('TLT')
# Out:
# iShares 20+ Year Treasury Bond
# Today is: 2020-07-24
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2019-07-15  128.01  128.60  128.01  128.52   6055500        0.0             0
# 2019-07-16  127.73  128.16  127.53  128.14   6172700        0.0             0
# 2019-07-17  128.61  129.55  128.60  129.52   9662200        0.0             0
# 2019-07-18  129.01  129.84  128.78  129.53   5724900        0.0             0
# 2019-07-19  129.13  129.46  129.05  129.22   5804800        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-07-17  167.27  167.40  166.47  166.78   8549900        0.0             0
# 2020-07-20  167.51  167.62  166.80  167.19   6907200        0.0             0
# 2020-07-21  167.30  167.72  167.08  167.29   8455100        0.0             0
# 2020-07-22  168.26  168.46  167.69  167.79   6592100        0.0             0
# 2020-07-23  168.92  169.88  168.48  169.75  10469400        0.0             0
#
# [260 rows x 7 columns]
# iShares 20+ Year Treasury Bond  price is: $169.75

# %%
#Charting test
tickers = ['DBC', 'TLT']
def create_plot(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    today = datetime.datetime.today().isoformat()
    
    ticker_df = ticker_data.history(period='1d', start='2020-01-1', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")
    plt.savefig(f'{tickersymbol}.png', bbox_inches="tight")
#create_plot('DBC')
#create_plot('TLT')
#create_plot('FXE')
create_plot('SPIP')

# %%
#Multiple Ticker Analysis

tickers = ['DBC', 'TLT']
start_date = "2020-05-29"

# %%
#Download stock data
stock_data = yf.download(tickers,start=start_date)

stock_data = stock_data.drop(columns=["Close", "High", "Low", "Open", "Volume"])
stock_data
# Out:
# [*********************100%***********************]  2 of 2 completed
#            Adj Close
#                  DBC         TLT
# Date
# 2020-05-29     11.78  163.188629
# 2020-06-01     11.85  162.089935
# 2020-06-02     11.98  161.500626
# 2020-06-03     11.98  159.353134
# 2020-06-04     12.08  157.045837
# 2020-06-05     12.32  155.927155
# 2020-06-08     12.24  156.526459
# 2020-06-09     12.28  158.304382
# 2020-06-10     12.36  160.651611
# 2020-06-11     11.96  163.688065
# 2020-06-12     12.01  162.109909
# 2020-06-15     12.12  162.199799
# 2020-06-16     12.22  159.712708
# 2020-06-17     12.16  160.371948
# 2020-06-18     12.23  162.069946
# 2020-06-19     12.33  162.199799
# 2020-06-22     12.46  162.219788
# 2020-06-23     12.40  161.111084
# 2020-06-24     12.09  162.839050
# 2020-06-25     12.20  163.308502
# 2020-06-26     12.05  165.056458
# 2020-06-29     12.25  164.537064
# 2020-06-30     12.31  163.737991
# 2020-07-01     12.41  163.419998
# 2020-07-02     12.46  163.589996
# 2020-07-06     12.56  162.919998
# 2020-07-07     12.57  165.210007
# 2020-07-08     12.73  164.550003
# 2020-07-09     12.58  167.169998
# 2020-07-10     12.66  166.330002
# 2020-07-13     12.53  166.880005
# 2020-07-14     12.59  167.119995
# 2020-07-15     12.74  166.339996
# 2020-07-16     12.64  167.130005
# 2020-07-17     12.66  166.779999
# 2020-07-20     12.65  167.190002
# 2020-07-21     12.83  167.289993
# 2020-07-22     12.91  167.789993
# 2020-07-23     12.88  169.750000
# 2020-07-24     12.88  169.749893

# %%
# calculate daily returns
stock_returns = stock_data.pct_change()
stock_returns = stock_returns.dropna()
stock_returns
# Out:
#            Adj Close
#                  DBC           TLT
# Date
# 2020-06-01  0.005942 -6.732662e-03
# 2020-06-02  0.010970 -3.635696e-03
# 2020-06-03  0.000000 -1.329711e-02
# 2020-06-04  0.008347 -1.447914e-02
# 2020-06-05  0.019868 -7.123289e-03
# 2020-06-08 -0.006494  3.843488e-03
# 2020-06-09  0.003268  1.135861e-02
# 2020-06-10  0.006515  1.482732e-02
# 2020-06-11 -0.032362  1.890086e-02
# 2020-06-12  0.004181 -9.641238e-03
# 2020-06-15  0.009159  5.544974e-04
# 2020-06-16  0.008251 -1.533350e-02
# 2020-06-17 -0.004910  4.127666e-03
# 2020-06-18  0.005757  1.058787e-02
# 2020-06-19  0.008177  8.012114e-04
# 2020-06-22  0.010543  1.232370e-04
# 2020-06-23 -0.004815 -6.834577e-03
# 2020-06-24 -0.025000  1.072531e-02
# 2020-06-25  0.009098  2.882920e-03
# 2020-06-26 -0.012295  1.070339e-02
# 2020-06-29  0.016597 -3.146765e-03
# 2020-06-30  0.004898 -4.856488e-03
# 2020-07-01  0.008123 -1.942085e-03
# 2020-07-02  0.004029  1.040253e-03
# 2020-07-06  0.008026 -4.095594e-03
# 2020-07-07  0.000796  1.405603e-02
# 2020-07-08  0.012729 -3.994938e-03
# 2020-07-09 -0.011783  1.592218e-02
# 2020-07-10  0.006359 -5.024803e-03
# 2020-07-13 -0.010269  3.306698e-03
# 2020-07-14  0.004789  1.438101e-03
# 2020-07-15  0.011914 -4.667298e-03
# 2020-07-16 -0.007849  4.749360e-03
# 2020-07-17  0.001582 -2.094215e-03
# 2020-07-20 -0.000790  2.458350e-03
# 2020-07-21  0.014229  5.980671e-04
# 2020-07-22  0.006235  2.988822e-03
# 2020-07-23 -0.002324  1.168131e-02
# 2020-07-24  0.000000 -6.292284e-07

# %%
# Clean and calculate cumulative returns finally chart
cumulative_returns = (1+stock_returns).cumprod()
ax = cumulative_returns.plot(figsize=(20,10), title="Commodities and Treasury yields indicating stagflation risk increasing")
ax.axis(["2020-06-01","2020-07-24",0.95,1.10])
ax.legend(["Invesco DB Commodity Tracking ETF", "iShares Barclays 20+ Yr Treas.Bond (TLT)"])
plt.savefig(f'Commodities_yields_cumulative_returns.png', bbox_inches="tight")

# %% [markdown]
# ## Risk Analysis
# (i) Volatility calculation
# (i) Charting volatility

# %%
stock_std = stock_returns.std()
stock_std
# Out:
# Adj Close  AAPL    0.017556
#            MSFT    0.016151
#            TSLA    0.034185
# dtype: float64

# %%
# Calculate the annualized standard deviation (252 trading days)
stock_std_annual = stock_std * np.sqrt(252)
stock_std_annual
# Out:
# Adj Close  AAPL    0.278695
#            MSFT    0.256388
#            TSLA    0.542671
# dtype: float64

# %%
# Realized volatility over 30 days

stock_std_rolling = stock_returns.rolling(window=30).std()
ax = stock_std_rolling.plot(figsize=(20,10),title = "30 day Rolling Standard Deviation")
#ax.axis(["2015-03-03", "2019-05-01", 0.0, 0.035])
