# %% [markdown]
# # Screen of Growth Indicators

# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
import os

# %matplotlib inline

# %%
from dotenv import load_dotenv
load_dotenv()
FRED_KEY = os.getenv("FRED_KEY")

# %%
from urllib.request import urlopen
import json

def get_jsonparsed_data(url):
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

# %% [markdown]
# ## Data Cleaning

# %%
# Pulling time series:
def pull_time_series(time_series_code, dataframe_name):

    url = (f"https://api.stlouisfed.org/fred/series/observations?series_id={time_series_code}&api_key={FRED_KEY}&file_type=json")
    raw_data = get_jsonparsed_data(url)
    dataframe_name = pd.DataFrame(raw_data['observations'])
    
    # convert to datetime
    dataframe_name['Date'] = pd.to_datetime(dataframe_name['date'])
    dataframe_name.set_index('Date', inplace=True)
    dataframe_name = dataframe_name.drop(columns=["date", "realtime_start", "realtime_end"]).sort_index()
    dataframe_name['value'] = pd.to_numeric(dataframe_name['value'],errors='coerce')
    return dataframe_name

# %%
# Pull Raw data for model
US_GDP_data = pull_time_series("A191RL1Q225SBEA", "US_GDP_Growth")

US_GDP_df = pull_time_series("GDPC1", "REAL_GDP")
US_Real_PCE_data = pull_time_series("PCEC96", "US_Real_PCE")
US_Initial_Claims_data = pull_time_series("ICSA", "US_Initial_Claims")
US_Cap_Util = pull_time_series("TCU", "US_Capital_Utilization")

US_Real_Disposable_Income = pull_time_series("DSPIC96", "Real_Disposable_Personal_Income")
US_Personal_Savings_Rate = pull_time_series("PSAVERT", "US_Personal_Savings_Rate_%_of_DPI")
US_M2_stock = pull_time_series("M2", "M2_Money_Stock")

# %%
# Setting up universal data cleaning functions for FRED data
def clean_data(df,variable_name):
    df.rename(columns={"value":variable_name},inplace=True)
    return df

# def set_date(df):
#     df = df.reset_index()
#     df["Date"] = df["Date"] - pd.Timedelta(1, unit='d')
#     df.set_index(df["Date"], inplace=True)
#     df = df.drop(columns=["Date"])
#     return df

def set_date_to_month_end(df):
    df.index = df.index.to_period('M').to_timestamp('M')
    return df

# %% [markdown]
# ### GDP Processing Section

# %%
# Change Column Name
clean_data(US_GDP_df, "Real GDP")

# Adding a YoY column
US_GDP_df["Real GDP YoY"] = US_GDP_df['Real GDP'].pct_change(4)*100
US_GDP_df["Real GDP"] = US_GDP_df["Real GDP"].replace(-np.inf, np.nan).dropna()


# Resetting Date Index to last day of each quarter
US_GDP_df = US_GDP_df.reset_index()
US_GDP_df["Date"] = US_GDP_df["Date"] - pd.Timedelta(1, unit='d')
US_GDP_df.set_index(US_GDP_df["Date"], inplace=True)
US_GDP_df = US_GDP_df.drop(columns=["Date"])


US_GDP_df.tail()
# Out:
#              Real GDP  Real GDP YoY
# Date
# 2019-03-31  19020.599      1.963163
# 2019-06-30  19141.744      2.076481
# 2019-09-30  19253.959      2.338885
# 2019-12-31  19010.848      0.319261
# 2020-03-31  17282.188     -9.139623

# %% [markdown]
# ### Macro Indicators Processing Section

# %%
# Clean PCE data
clean_data(US_Real_PCE_data, "Real_PCE")
US_Real_PCE_data["Real_PCE_YoY"] = US_Real_PCE_data['Real_PCE'].pct_change(12)*100
US_Real_PCE_data["Real_PCE_YoY"] = US_Real_PCE_data["Real_PCE_YoY"].replace(-np.inf, np.nan).dropna()

# Changing date index to last day of the month
US_Real_PCE_data = set_date_to_month_end(US_Real_PCE_data)

US_Real_PCE_data.tail()
# Out:
#             Real_PCE  Real_PCE_YoY
# Date
# 2020-03-31   12536.1     -4.694532
# 2020-04-30   10977.0    -16.698919
# 2020-05-31   11904.1     -9.882964
# 2020-06-30   12577.6     -5.084029
# 2020-07-31   12778.2     -3.771368

# %%
# Clean US Initial Claims data
clean_data(US_Initial_Claims_data, "Initial_Claims")

# Resample Weekly data to Monthly
US_Initial_Claims_data_resampled = US_Initial_Claims_data.Initial_Claims.resample('M').sum()
US_Initial_Claims_data_resampled = pd.DataFrame(US_Initial_Claims_data_resampled)

# Calculate YoY change
US_Initial_Claims_data_resampled["Initial_Claims_YoY"] = US_Initial_Claims_data_resampled['Initial_Claims'].pct_change(12)*100
US_Initial_Claims_data_resampled["Initial_Claims_YoY"] = US_Initial_Claims_data_resampled["Initial_Claims_YoY"].replace(-np.inf, np.nan).dropna()
US_Initial_Claims_data_resampled.tail()
# Out:
#             Initial_Claims  Initial_Claims_YoY
# Date
# 2020-05-31        12329000         1312.256586
# 2020-06-30         5996000          442.624434
# 2020-07-31         5475000          540.350877
# 2020-08-31         5161000          377.428307
# 2020-09-30          884000            3.755869

# %%
# Clean capacity utilization data
clean_data(US_Cap_Util, "Capacity_Utilization")
US_Cap_Util["Cap_Util_YoY_Change"] = US_Cap_Util['Capacity_Utilization'].pct_change(12)*100
US_Cap_Util["Cap_Util_YoY_Change"] = US_Cap_Util["Cap_Util_YoY_Change"].replace(-np.inf, np.nan).dropna()

# Changing date index to last day of the month
US_Cap_Util = set_date_to_month_end(US_Cap_Util)

US_Cap_Util.tail()
# Out:
#             Capacity_Utilization  Cap_Util_YoY_Change
# Date
# 2020-03-31               73.6134            -6.103680
# 2020-04-30               64.1954           -17.448752
# 2020-05-31               64.7785           -16.732223
# 2020-06-30               68.4643           -11.880347
# 2020-07-31               70.5584            -8.867535

# %%
# Clean US_Personal_Savings_Rate data

clean_data(US_Personal_Savings_Rate, "US_Personal_Savings_Rate_%_of_DPI")
US_Personal_Savings_Rate["US_Personal_Savings_Rate_%_of_DPI_YoY"] = US_Personal_Savings_Rate['US_Personal_Savings_Rate_%_of_DPI'].pct_change(12)*100
US_Personal_Savings_Rate["US_Personal_Savings_Rate_%_of_DPI_YoY"] = US_Personal_Savings_Rate["US_Personal_Savings_Rate_%_of_DPI_YoY"].replace(-np.inf, np.nan).dropna()

# Changing date index to last day of the month
US_Personal_Savings_Rate = set_date_to_month_end(US_Personal_Savings_Rate)

US_Personal_Savings_Rate.tail()
# Out:
#             US_Personal_Savings_Rate_%_of_DPI  \
# Date
# 2020-03-31                               12.9
# 2020-04-30                               33.7
# 2020-05-31                               24.6
# 2020-06-30                               19.2
# 2020-07-31                               17.8
#
#             US_Personal_Savings_Rate_%_of_DPI_YoY
# Date
# 2020-03-31                              61.250000
# 2020-04-30                             349.333333
# 2020-05-31                             236.986301
# 2020-06-30                             170.422535
# 2020-07-31                             154.285714

# %%
US_Personal_Savings_Rate.tail()
# Out:
#             US_Personal_Savings_Rate_%_of_DPI  \
# Date
# 2020-03-31                               12.9
# 2020-04-30                               33.7
# 2020-05-31                               24.6
# 2020-06-30                               19.2
# 2020-07-31                               17.8
#
#             US_Personal_Savings_Rate_%_of_DPI_YoY
# Date
# 2020-03-31                              61.250000
# 2020-04-30                             349.333333
# 2020-05-31                             236.986301
# 2020-06-30                             170.422535
# 2020-07-31                             154.285714

# %%
# Clean US_Real_Disposable_Income data

clean_data(US_Real_Disposable_Income, "US_Real_DPI")
US_Real_Disposable_Income["Real_DPI_YoY"] = US_Real_Disposable_Income['US_Real_DPI'].pct_change(12)*100
US_Real_Disposable_Income["Real_DPI_YoY"] = US_Real_Disposable_Income["Real_DPI_YoY"].replace(-np.inf, np.nan).dropna()

# Changing date index to last day of the month
US_Real_Disposable_Income = set_date_to_month_end(US_Real_Disposable_Income)

US_Real_Disposable_Income.tail()
# Out:
#             US_Real_DPI  Real_DPI_YoY
# Date
# 2020-03-31      14949.3      0.630061
# 2020-04-30      17254.7     16.450476
# 2020-05-31      16400.8     10.744382
# 2020-06-30      16107.2      8.635714
# 2020-07-31      16091.6      8.431770

# %%
# Clean M2 Money stock data
clean_data(US_M2_stock, "M2")
M2_stock_resampled = US_M2_stock.resample('M').last()

# Calculate Monthly percentage change
M2_stock_resampled["M2_Money_Supply_YoY"] = M2_stock_resampled['M2'].pct_change(12)*100
M2_stock_resampled["M2_Money_Supply_YoY"] = M2_stock_resampled["M2_Money_Supply_YoY"].replace(-np.inf, np.nan).dropna()
M2_stock_resampled.tail(13)
# Out:
#                  M2  M2_Money_Supply_YoY
# Date
# 2019-08-31  14938.2             4.993780
# 2019-09-30  15086.4             5.975077
# 2019-10-31  15189.1             6.605138
# 2019-11-30  15282.4             7.193760
# 2019-12-31  15333.6             6.388027
# 2020-01-31  15445.3             6.724663
# 2020-02-29  15434.1             6.653169
# 2020-03-31  16533.3            13.860213
# 2020-04-30  17406.4            19.312628
# 2020-05-31  17938.5            22.058013
# 2020-06-30  18233.4            23.214467
# 2020-07-31  18284.4            22.684452
# 2020-08-31  18464.4            23.605254

# %% [markdown]
# ### Final Summary Section
#
# Here I concat all the separate factor dataframes and transpose to show the last years worth of values. The summary dataframes are then broken out between raw values and Year-over-Year values. These dataframes are then exported to excel for display purposes.

# %%
# Concat dataframes
master_df = pd.concat([US_Real_PCE_data,
                       US_Initial_Claims_data_resampled, 
                       US_Cap_Util,
                       US_Real_Disposable_Income,
                       US_Personal_Savings_Rate, 
                       M2_stock_resampled], axis="columns", join='inner')

master_df = master_df.iloc[-50:,:]

# %%
# Transpose Dataframe

master_df_transposed = master_df.transpose()
master_df_transposed = master_df_transposed.round(decimals=2)
master_df_transposed = master_df_transposed.iloc[:,-13:]
master_df_transposed_copy = master_df_transposed.copy()

# %%
# Rate of Change Summary

master_YoY_df = master_df.drop(columns=["Real_PCE","Initial_Claims", "Capacity_Utilization", "US_Real_DPI", "US_Personal_Savings_Rate_%_of_DPI","M2"])
master_YoY_df_transposed = master_YoY_df.transpose()

master_YoY_df_transposed = master_YoY_df_transposed.round(decimals=2)
master_YoY_df_transposed = master_YoY_df_transposed.iloc[:,-13:]
master_YoY_df_transposed
# Out:
# Date                                   2019-07-31  2019-08-31  2019-09-30  \
# Real_PCE_YoY                                 2.44        2.33        2.58
# Initial_Claims_YoY                          -1.16       25.55      -19.85
# Cap_Util_YoY_Change                         -1.72       -1.82       -2.30
# Real_DPI_YoY                                 1.58        1.79        2.02
# US_Personal_Savings_Rate_%_of_DPI_YoY      -11.39       -6.41       -7.59
# M2_Money_Supply_YoY                          5.26        4.99        5.98
#
# Date                                   2019-10-31  2019-11-30  2019-12-31  \
# Real_PCE_YoY                                 2.30        2.06        3.02
# Initial_Claims_YoY                          -0.23       20.81      -17.67
# Cap_Util_YoY_Change                         -2.90       -2.51       -2.89
# Real_DPI_YoY                                 1.81        2.10        0.83
# US_Personal_Savings_Rate_%_of_DPI_YoY       -5.26        1.35      -20.88
# M2_Money_Supply_YoY                          6.61        7.19        6.39
#
# Date                                   2020-01-31  2020-02-29  2020-03-31  \
# Real_PCE_YoY                                 2.69        2.61       -4.69
# Initial_Claims_YoY                          -3.41       17.44      879.52
# Cap_Util_YoY_Change                         -2.70       -1.95       -6.10
# Real_DPI_YoY                                 1.55        2.01        0.63
# US_Personal_Savings_Rate_%_of_DPI_YoY      -10.59       -3.49       61.25
# M2_Money_Supply_YoY                          6.72        6.65       13.86
#
# Date                                   2020-04-30  2020-05-31  2020-06-30  \
# Real_PCE_YoY                               -16.70       -9.88       -5.08
# Initial_Claims_YoY                        2238.86     1312.26      442.62
# Cap_Util_YoY_Change                        -17.45      -16.73      -11.88
# Real_DPI_YoY                                16.45       10.74        8.64
# US_Personal_Savings_Rate_%_of_DPI_YoY      349.33      236.99      170.42
# M2_Money_Supply_YoY                         19.31       22.06       23.21
#
# Date                                   2020-07-31
# Real_PCE_YoY                                -3.77
# Initial_Claims_YoY                         540.35
# Cap_Util_YoY_Change                         -8.87
# Real_DPI_YoY                                 8.43
# US_Personal_Savings_Rate_%_of_DPI_YoY      154.29
# M2_Money_Supply_YoY                         22.68

# %%
# Factor Summary

master_factor_df = master_df.drop(columns=["Real_PCE_YoY",
                                        "Initial_Claims_YoY", 
                                        "Cap_Util_YoY_Change", 
                                        "Real_DPI_YoY", 
                                        "US_Personal_Savings_Rate_%_of_DPI_YoY",
                                        "M2_Money_Supply_YoY"])

master_factor_df_transposed = master_factor_df.transpose()

master_factor_df_transposed = master_factor_df_transposed.round(decimals=2)
master_factor_df_transposed = master_factor_df_transposed.iloc[:,-13:]
master_factor_df_transposed
# Out:
# Date                               2019-07-31  2019-08-31  2019-09-30  \
# Real_PCE                             13279.00    13305.50    13319.50
# Initial_Claims                      855000.00  1081000.00   852000.00
# Capacity_Utilization                    77.42       77.84       77.43
# US_Real_DPI                          14840.30    14912.40    14933.60
# US_Personal_Savings_Rate_%_of_DPI        7.00        7.30        7.30
# M2                                   14903.60    14938.20    15086.40
#
# Date                               2019-10-31  2019-11-30  2019-12-31  \
# Real_PCE                             13344.30    13356.20    13360.60
# Initial_Claims                      860000.00  1074000.00   904000.00
# Capacity_Utilization                    76.99       77.57       77.17
# US_Real_DPI                          14936.20    14997.20    14960.20
# US_Personal_Savings_Rate_%_of_DPI        7.20        7.50        7.20
# M2                                   15189.10    15282.40    15333.60
#
# Date                               2020-01-31  2020-02-29   2020-03-31  \
# Real_PCE                             13416.70    13402.40     12536.10
# Initial_Claims                      851000.00  1057000.00  10667000.00
# Capacity_Utilization                    76.88       76.93        73.61
# US_Real_DPI                          15070.20    15162.60     14949.30
# US_Personal_Savings_Rate_%_of_DPI        7.60        8.30        12.90
# M2                                   15445.30    15434.10     16533.30
#
# Date                               2020-04-30   2020-05-31  2020-06-30  \
# Real_PCE                              10977.0     11904.10    12577.60
# Initial_Claims                     20161000.0  12329000.00  5996000.00
# Capacity_Utilization                     64.2        64.78       68.46
# US_Real_DPI                           17254.7     16400.80    16107.20
# US_Personal_Savings_Rate_%_of_DPI        33.7        24.60       19.20
# M2                                    17406.4     17938.50    18233.40
#
# Date                               2020-07-31
# Real_PCE                             12778.20
# Initial_Claims                     5475000.00
# Capacity_Utilization                    70.56
# US_Real_DPI                          16091.60
# US_Personal_Savings_Rate_%_of_DPI       17.80
# M2                                   18284.40

# %%
# Export to XLSX
import xlsxwriter
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('US_Macro_Screen.xlsx', engine='xlsxwriter', date_format='yyyy mm dd', datetime_format='yyyy mm dd')

# Convert the dataframe to an XlsxWriter Excel object.
master_df_transposed.to_excel(writer, sheet_name='US_Macro_Screen', float_format='%.2f')
master_YoY_df_transposed.to_excel(writer, sheet_name='US_Factors_YoY', float_format='%.2f')
master_factor_df_transposed.to_excel(writer, sheet_name='US_Raw_Factors', float_format='%.2f')
# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Charting Section

# %%
# Chart US_Personal_Savings_Rate_%_of_DPI
x = master_factor_df.index
y = master_factor_df["US_Personal_Savings_Rate_%_of_DPI"]
plt.subplots(figsize=(15,8))
plt.plot(x,y, label="US Personal Savings Rate % of DPI", linewidth=3, color="#008000")

plt.legend(prop={'size': 16})
plt.xlabel("Date")
plt.title(f"US Personal Savings Rate % of Disposable Personal Income (DPI)", fontdict={'fontweight':'bold', 'fontsize':'22'})
plt.savefig(f'Images/Macro_Screen/US_Personal_Savings_Rate_%_of_DPI.png', bbox_inches="tight")
plt.show()

# %%
# Chart US M2 Money Supply
x = master_factor_df.index
y = master_factor_df["M2"]
plt.subplots(figsize=(15,8))
plt.plot(x,y, label="US M2 Money Supply", linewidth=3, color="blue")

plt.legend(prop={'size': 16})
plt.xlabel("Date")
plt.ylabel("M2 (Billions of Dollars, Seasonally Adjusted)")
plt.title(f"US M2 Money Supply", fontdict={'fontweight':'bold', 'fontsize':'22'})
plt.savefig(f'Images/Macro_Screen/US M2 Money Supply.png', bbox_inches="tight")
plt.show()

# %%
# Chart US M2 Money Supply YoY
x = master_YoY_df.index
y = master_YoY_df["M2_Money_Supply_YoY"]
plt.subplots(figsize=(15,8))
plt.plot(x,y, label="US M2 Money Supply YoY% Growth", linewidth=3, color="blue")

plt.legend(prop={'size': 16})
plt.xlabel("Date")
plt.ylabel("YoY % Growth (Monthly)")
plt.title(f"US M2 Money Supply YoY % Growth (Monthly)", fontdict={'fontweight':'bold', 'fontsize':'22'})
plt.savefig(f'Images/Macro_Screen/US_M2_Money_Supply_YoY.png', bbox_inches="tight")
plt.show()

# %%
# M2 vs. GDP
# Concat GDP and M2 dataframes
GDP_M2_df = pd.concat([US_GDP_df,
                       M2_stock_resampled], axis="columns", join='inner')
GDP_M2_df.tail()
# Out:
#              Real GDP  Real GDP YoY       M2  M2_Money_Supply_YoY
# Date
# 2019-03-31  19020.599      1.963163  14520.7             3.939787
# 2019-06-30  19141.744      2.076481  14798.1             4.714898
# 2019-09-30  19253.959      2.338885  15086.4             5.975077
# 2019-12-31  19010.848      0.319261  15333.6             6.388027
# 2020-03-31  17282.188     -9.139623  16533.3            13.860213

# %%
GDP_M2_df["M2 % of Real GDP"] = (GDP_M2_df["M2"]/GDP_M2_df["Real GDP"])*100
GDP_M2_df.tail()
# Out:
#              Real GDP  Real GDP YoY       M2  M2_Money_Supply_YoY  \
# Date
# 2019-03-31  19020.599      1.963163  14520.7             3.939787
# 2019-06-30  19141.744      2.076481  14798.1             4.714898
# 2019-09-30  19253.959      2.338885  15086.4             5.975077
# 2019-12-31  19010.848      0.319261  15333.6             6.388027
# 2020-03-31  17282.188     -9.139623  16533.3            13.860213
#
#             M2 % of Real GDP
# Date
# 2019-03-31         76.341970
# 2019-06-30         77.308003
# 2019-09-30         78.354794
# 2019-12-31         80.657107
# 2020-03-31         95.666706

# %%
# Plot M2 as a % of Real GDP
# x = master_factor_df.index
# y = master_factor_df["M2"]
plt.subplots(figsize=(15,8))
plt.plot(GDP_M2_df["M2 % of Real GDP"], label="M2 % of Real GDP", linewidth=3, color="#008000")

plt.legend(prop={'size': 16})
plt.xlabel("Date")
plt.ylabel("Percentage of GDP")
plt.title(f"US M2 Money Supply as a Percentage of Real GDP", fontdict={'fontweight':'bold', 'fontsize':'22'})
plt.savefig(f'Images/Macro_Screen/M2 % of Real GDP.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Conditional Formatting Section

# %%
#Conditional formatting
# highlight red if negative
def color_negative(number):
    color = 'red' if number < 0 else 'black'
    return f'color: {color}'

# master_df_transposed.style.applymap(color_negative)
Real_PCE_YoY = master_df_transposed.loc[["Real_PCE_YoY"]].style.applymap(color_negative)
Real_PCE_YoY
# Out:
# <style  type="text/css" >
#     #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col0 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col1 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col2 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col3 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col4 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col5 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col6 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col7 {
#             color:  black;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col8 {
#             color:  red;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col9 {
#             color:  red;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col10 {
#             color:  red;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col11 {
#             color:  red;
#         }    #T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col12 {
#             color:  red;
#         }</style><table id="T_110ec64a_f6cf_11ea_a481_c8348e32f095" ><thead>    <tr>        <th class="index_name level0" >Date</th>        <th class="col_heading level0 col0" >2019-07-31 00:00:00</th>        <th class="col_heading level0 col1" >2019-08-31 00:00:00</th>        <th class="col_heading level0 col2" >2019-09-30 00:00:00</th>        <th class="col_heading level0 col3" >2019-10-31 00:00:00</th>        <th class="col_heading level0 col4" >2019-11-30 00:00:00</th>        <th class="col_heading level0 col5" >2019-12-31 00:00:00</th>        <th class="col_heading level0 col6" >2020-01-31 00:00:00</th>        <th class="col_heading level0 col7" >2020-02-29 00:00:00</th>        <th class="col_heading level0 col8" >2020-03-31 00:00:00</th>        <th class="col_heading level0 col9" >2020-04-30 00:00:00</th>        <th class="col_heading level0 col10" >2020-05-31 00:00:00</th>        <th class="col_heading level0 col11" >2020-06-30 00:00:00</th>        <th class="col_heading level0 col12" >2020-07-31 00:00:00</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_110ec64a_f6cf_11ea_a481_c8348e32f095level0_row0" class="row_heading level0 row0" >Real_PCE_YoY</th>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col0" class="data row0 col0" >2.440000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col1" class="data row0 col1" >2.330000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col2" class="data row0 col2" >2.580000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col3" class="data row0 col3" >2.300000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col4" class="data row0 col4" >2.060000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col5" class="data row0 col5" >3.020000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col6" class="data row0 col6" >2.690000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col7" class="data row0 col7" >2.610000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col8" class="data row0 col8" >-4.690000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col9" class="data row0 col9" >-16.700000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col10" class="data row0 col10" >-9.880000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col11" class="data row0 col11" >-5.080000</td>
#                         <td id="T_110ec64a_f6cf_11ea_a481_c8348e32f095row0_col12" class="data row0 col12" >-3.770000</td>
#             </tr>
#     </tbody></table>

# %%
master_df_transposed.loc["Real_PCE_YoY"] = Real_PCE_YoY
# master_df_transposed = master_df_transposed_copy
master_df_transposed
# Out:
# Date                                                                          2019-07-31  \
# Real_PCE                                                                           13279
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                    855000
# Initial_Claims_YoY                                                                 -1.16
# Capacity_Utilization                                                               77.42
# Cap_Util_YoY_Change                                                                -1.72
# US_Real_DPI                                                                      14840.3
# Real_DPI_YoY                                                                        1.58
# US_Personal_Savings_Rate_%_of_DPI                                                      7
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             -11.39
# M2                                                                               14903.6
# M2_Money_Supply_YoY                                                                 5.26
#
# Date                                                                          2019-08-31  \
# Real_PCE                                                                         13305.5
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                 1.081e+06
# Initial_Claims_YoY                                                                 25.55
# Capacity_Utilization                                                               77.84
# Cap_Util_YoY_Change                                                                -1.82
# US_Real_DPI                                                                      14912.4
# Real_DPI_YoY                                                                        1.79
# US_Personal_Savings_Rate_%_of_DPI                                                    7.3
# US_Personal_Savings_Rate_%_of_DPI_YoY                                              -6.41
# M2                                                                               14938.2
# M2_Money_Supply_YoY                                                                 4.99
#
# Date                                                                          2019-09-30  \
# Real_PCE                                                                         13319.5
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                    852000
# Initial_Claims_YoY                                                                -19.85
# Capacity_Utilization                                                               77.43
# Cap_Util_YoY_Change                                                                 -2.3
# US_Real_DPI                                                                      14933.6
# Real_DPI_YoY                                                                        2.02
# US_Personal_Savings_Rate_%_of_DPI                                                    7.3
# US_Personal_Savings_Rate_%_of_DPI_YoY                                              -7.59
# M2                                                                               15086.4
# M2_Money_Supply_YoY                                                                 5.98
#
# Date                                                                          2019-10-31  \
# Real_PCE                                                                         13344.3
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                    860000
# Initial_Claims_YoY                                                                 -0.23
# Capacity_Utilization                                                               76.99
# Cap_Util_YoY_Change                                                                 -2.9
# US_Real_DPI                                                                      14936.2
# Real_DPI_YoY                                                                        1.81
# US_Personal_Savings_Rate_%_of_DPI                                                    7.2
# US_Personal_Savings_Rate_%_of_DPI_YoY                                              -5.26
# M2                                                                               15189.1
# M2_Money_Supply_YoY                                                                 6.61
#
# Date                                                                          2019-11-30  \
# Real_PCE                                                                         13356.2
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                 1.074e+06
# Initial_Claims_YoY                                                                 20.81
# Capacity_Utilization                                                               77.57
# Cap_Util_YoY_Change                                                                -2.51
# US_Real_DPI                                                                      14997.2
# Real_DPI_YoY                                                                         2.1
# US_Personal_Savings_Rate_%_of_DPI                                                    7.5
# US_Personal_Savings_Rate_%_of_DPI_YoY                                               1.35
# M2                                                                               15282.4
# M2_Money_Supply_YoY                                                                 7.19
#
# Date                                                                          2019-12-31  \
# Real_PCE                                                                         13360.6
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                    904000
# Initial_Claims_YoY                                                                -17.67
# Capacity_Utilization                                                               77.17
# Cap_Util_YoY_Change                                                                -2.89
# US_Real_DPI                                                                      14960.2
# Real_DPI_YoY                                                                        0.83
# US_Personal_Savings_Rate_%_of_DPI                                                    7.2
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             -20.88
# M2                                                                               15333.6
# M2_Money_Supply_YoY                                                                 6.39
#
# Date                                                                          2020-01-31  \
# Real_PCE                                                                         13416.7
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                    851000
# Initial_Claims_YoY                                                                 -3.41
# Capacity_Utilization                                                               76.88
# Cap_Util_YoY_Change                                                                 -2.7
# US_Real_DPI                                                                      15070.2
# Real_DPI_YoY                                                                        1.55
# US_Personal_Savings_Rate_%_of_DPI                                                    7.6
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             -10.59
# M2                                                                               15445.3
# M2_Money_Supply_YoY                                                                 6.72
#
# Date                                                                          2020-02-29  \
# Real_PCE                                                                         13402.4
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                 1.057e+06
# Initial_Claims_YoY                                                                 17.44
# Capacity_Utilization                                                               76.93
# Cap_Util_YoY_Change                                                                -1.95
# US_Real_DPI                                                                      15162.6
# Real_DPI_YoY                                                                        2.01
# US_Personal_Savings_Rate_%_of_DPI                                                    8.3
# US_Personal_Savings_Rate_%_of_DPI_YoY                                              -3.49
# M2                                                                               15434.1
# M2_Money_Supply_YoY                                                                 6.65
#
# Date                                                                          2020-03-31  \
# Real_PCE                                                                         12536.1
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                1.0667e+07
# Initial_Claims_YoY                                                                879.52
# Capacity_Utilization                                                               73.61
# Cap_Util_YoY_Change                                                                 -6.1
# US_Real_DPI                                                                      14949.3
# Real_DPI_YoY                                                                        0.63
# US_Personal_Savings_Rate_%_of_DPI                                                   12.9
# US_Personal_Savings_Rate_%_of_DPI_YoY                                              61.25
# M2                                                                               16533.3
# M2_Money_Supply_YoY                                                                13.86
#
# Date                                                                          2020-04-30  \
# Real_PCE                                                                           10977
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                2.0161e+07
# Initial_Claims_YoY                                                               2238.86
# Capacity_Utilization                                                                64.2
# Cap_Util_YoY_Change                                                               -17.45
# US_Real_DPI                                                                      17254.7
# Real_DPI_YoY                                                                       16.45
# US_Personal_Savings_Rate_%_of_DPI                                                   33.7
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             349.33
# M2                                                                               17406.4
# M2_Money_Supply_YoY                                                                19.31
#
# Date                                                                          2020-05-31  \
# Real_PCE                                                                         11904.1
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                1.2329e+07
# Initial_Claims_YoY                                                               1312.26
# Capacity_Utilization                                                               64.78
# Cap_Util_YoY_Change                                                               -16.73
# US_Real_DPI                                                                      16400.8
# Real_DPI_YoY                                                                       10.74
# US_Personal_Savings_Rate_%_of_DPI                                                   24.6
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             236.99
# M2                                                                               17938.5
# M2_Money_Supply_YoY                                                                22.06
#
# Date                                                                          2020-06-30  \
# Real_PCE                                                                         12577.6
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                 5.996e+06
# Initial_Claims_YoY                                                                442.62
# Capacity_Utilization                                                               68.46
# Cap_Util_YoY_Change                                                               -11.88
# US_Real_DPI                                                                      16107.2
# Real_DPI_YoY                                                                        8.64
# US_Personal_Savings_Rate_%_of_DPI                                                   19.2
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             170.42
# M2                                                                               18233.4
# M2_Money_Supply_YoY                                                                23.21
#
# Date                                                                          2020-07-31
# Real_PCE                                                                         12778.2
# Real_PCE_YoY                           <pandas.io.formats.style.Styler object at 0x00...
# Initial_Claims                                                                 5.475e+06
# Initial_Claims_YoY                                                                540.35
# Capacity_Utilization                                                               70.56
# Cap_Util_YoY_Change                                                                -8.87
# US_Real_DPI                                                                      16091.6
# Real_DPI_YoY                                                                        8.43
# US_Personal_Savings_Rate_%_of_DPI                                                   17.8
# US_Personal_Savings_Rate_%_of_DPI_YoY                                             154.29
# M2                                                                               18284.4
# M2_Money_Supply_YoY                                                                22.68

# %%
master_df_transposed.iloc[1].style.background_gradient(cmap='PuBu', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-60c647bbd271> in <module>
# ----> 1 master_df_transposed.iloc[1].style.background_gradient(cmap='PuBu', axis=1)
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'style'

# %%
import seaborn as sns

cm = sns.light_palette("red", as_cmap=True)

master_df_transposed.iloc[:,-10:].style.background_gradient(cmap=cm, axis=1)
# Out:
# <style  type="text/css" >
#     #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col0 {
#             background-color:  #ff0606;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col1 {
#             background-color:  #ff0505;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col2 {
#             background-color:  #ff0505;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col4 {
#             background-color:  #ff0101;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col5 {
#             background-color:  #ff5353;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col7 {
#             background-color:  #ff8e8e;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col8 {
#             background-color:  #ff4f4f;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row0_col9 {
#             background-color:  #ff3b3b;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col0 {
#             background-color:  #ff0808;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col1 {
#             background-color:  #ff0b0b;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col3 {
#             background-color:  #ff0404;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col4 {
#             background-color:  #ff0505;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col5 {
#             background-color:  #ff5a5a;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col7 {
#             background-color:  #ff9696;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col8 {
#             background-color:  #ff5e5e;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row1_col9 {
#             background-color:  #ff4f4f;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col1 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col4 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col5 {
#             background-color:  #ff7070;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col6 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col7 {
#             background-color:  #ff5d5d;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col8 {
#             background-color:  #ffa8a8;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row2_col9 {
#             background-color:  #ffafaf;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col1 {
#             background-color:  #ffe2e2;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col4 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col5 {
#             background-color:  #ff8b8b;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col6 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col7 {
#             background-color:  #ff5e5e;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col8 {
#             background-color:  #ffb7b7;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row3_col9 {
#             background-color:  #ffadad;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col0 {
#             background-color:  #ff0a0a;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col2 {
#             background-color:  #ff0606;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col3 {
#             background-color:  #ff0c0c;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col4 {
#             background-color:  #ff0b0b;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col5 {
#             background-color:  #ff4444;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col7 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col8 {
#             background-color:  #ff9d9d;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row4_col9 {
#             background-color:  #ff7979;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col0 {
#             background-color:  #ff0e0e;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col1 {
#             background-color:  #ff0808;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col2 {
#             background-color:  #ff0e0e;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col3 {
#             background-color:  #ff0b0b;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col4 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col5 {
#             background-color:  #ff3d3d;
#             color:  #f1f1f1;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col7 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col8 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_5877b17a_f11e_11ea_bc55_c8348e32f095row5_col9 {
#             background-color:  #ff6767;
#             color:  #000000;
